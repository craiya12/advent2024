# %%
import os
import pandas as pd
import numpy as np
import re
import copy 

# Define the file path
file_path = "advent_9_test.txt"

# Open the file and read the content
with open(file_path, "r") as file:
    digit_string = file.read().strip()  # Read and remove any extra whitespaces/newlines

# %%
digit_list=[]

file_content=0

turn='file_s'

for num in digit_string:
    if turn=='file_s' and num!='0':
        
        num_list=[]
        
        for i in range(int(num)):
            num_list.append(str(file_content))
        digit_list.append(num_list)
        turn='file_f'
        file_content+=1
    elif turn=='file_f'and num !='0':
        
        dot_list=[]
        
        for j in range(int(num)):
            dot_list.append('.')
        digit_list.append(dot_list)    
        turn='file_s'
            
    else:
        if turn=='file_s':
            turn='file_f'
        else:
            turn='file_s'

print(digit_list)
#print(''.join(digit_list))
# Out:
# [['0', '0'], ['.', '.', '.'], ['1', '1', '1'], ['.', '.', '.'], ['2'], ['.', '.', '.'], ['3', '3', '3'], ['.'], ['4', '4'], ['.'], ['5', '5', '5', '5'], ['.'], ['6', '6', '6', '6'], ['.'], ['7', '7', '7'], ['.'], ['8', '8', '8', '8'], ['9', '9']]

# %%
'''
progress_list=digit_list.copy()

#progress_list=test_test_list

forward=True

i=0

while forward==True:
    
    j=len(progress_list)-1
    
    if progress_list[i]=='.':
        backward=True
        print("working", j,i)
        
        while backward==True:
            if i>j:
                   
                forward=False
                break

            if progress_list[j]!='.':
                transfer_num=progress_list[j]
                #print(transfer_num, i, j, progress_list[i],progress_list[j])
                
                del progress_list[j]
                progress_list.insert(j,'.')
                
                del progress_list[i]
                progress_list.insert(i,transfer_num)
                
                backward=False
                

                #i=0
                break
                
                
                
            j=j-1
    i+=1

        
total_sum=0

for i,item in enumerate(progress_list):
    if item=='.':
        break
    total_sum=total_sum+i*int(item)
        
#print(''.join(progress_list))
print(total_sum)

'''

print(digit_list)
# Out:
# [['0', '0'], ['.', '.', '.'], ['1', '1', '1'], ['.', '.', '.'], ['2'], ['.', '.', '.'], ['3', '3', '3'], ['.'], ['4', '4'], ['.'], ['5', '5', '5', '5'], ['.'], ['6', '6', '6', '6'], ['.'], ['7', '7', '7'], ['.'], ['8', '8', '8', '8'], ['9', '9']]

# %%
progress_list=copy.deepcopy(digit_list)
backward=True
j=len(progress_list)-1

while backward==True:
    
    i=0

    
    forward=True
    
    while forward==True:
        
        if j<0:
            backward=False
            break
        
        if len(progress_list[j])<len(progress_list[i]) and progress_list[i][0]=='.':
                
                
                final_list=[]
                for k in progress_list:
                    for l in k:
                        final_list.append(l)
                print(''.join(final_list))
                
                
                
                
                transfer_list=progress_list[j].copy()
                
                for m in range(len(progress_list[j])):
                    progress_list[j][m]='.'
                
                progress_list.insert(i,transfer_list)
                
                
                
                for k in range(len(transfer_list)):
                    progress_list[i+1].remove('.')


                j=j+1
                print(j)
                print(progress_list)

                forward=False
        elif i+1>len(progress_list):
            forward=False
                

                    
        
        i+=1
    
    
    
    j=j-1

    
#print(progress_list)
    
final_list=[]
for k in progress_list:
    for l in k:
        final_list.append(l)
        
        
        
print(''.join(final_list))
# Out:
# 00...111...2...333.44.5555.6666.777.888899
# 18
# [['0', '0'], ['9', '9'], ['.'], ['1', '1', '1'], ['.', '.', '.'], ['2'], ['.', '.', '.'], ['3', '3', '3'], ['.'], ['4', '4'], ['.'], ['5', '5', '5', '5'], ['.'], ['6', '6', '6', '6'], ['.'], ['7', '7', '7'], ['.'], ['8', '8', '8', '8'], ['.', '.']]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[147], line 18
#      15     backward=False
#      16     break
# ---> 18 if len(progress_list[j])<len(progress_list[i]) and progress_list[i][0]=='.':
#      21         final_list=[]
#      22         for k in progress_list:
#
# IndexError: list index out of range
