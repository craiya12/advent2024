# %%
import os
import pandas as pd
import numpy as np

file=open('advent_2.txt','r')

content=file.readlines()

file_test=open('advent_2_test.txt','r')

content_test=file_test.readlines()

print(content_test)
# Out:
# ['7 6 4 2 1\n', '1 2 7 8 9\n', '9 7 6 2 1\n', '1 3 2 4 5\n', '8 6 4 4 1\n', '1 3 6 7 9']

# %%
reports=[]

for line in content:
    
    data=line.split()
    
    int_data=np.array(data).astype(int).item
    
    reports.append(line.split())

# %%
'''

counter=0

test_reports=reports[4:5]

failed_lines=[]

fail=0

for line in reports:
    x_0=np.nan
    good=True
    up=False
    down=False


    i=0
    
    for number in line:
        

        if x_0 is np.nan:
            x_0=float(number)
            i=i+1
            
        elif float(number)>x_0 and (float(number)-x_0)<=3 and down==False:
            x_0=float(number)
            up=True
            i=i+1

            
        elif float(number)<x_0 and (x_0-float(number))<=3 and up==False:
            x_0=float(number)
            down=True
            i=i+1
            
        else:
            
            if good==True:
                fail=i-1
            
            good=False
            
            
                
    if good==False:
        
        f_line=line[:fail] + line[fail+1:]
        
        failed_lines.append(f_line)
            
            
    if good==True:
        counter=counter+1
        print(line)


print(failed_lines)

for line in failed_lines:
    x_0=np.nan
    good=True
    up=False
    down=False


    i=0
    
    for number in line:
        

        if x_0 is np.nan:
            x_0=float(number)
            i=i+1
            
        elif float(number)>x_0 and (float(number)-x_0)<=3 and down==False:
            x_0=float(number)
            up=True
            i=i+1

            
        elif float(number)<x_0 and (x_0-float(number))<=3 and up==False:
            x_0=float(number)
            down=True
            i=i+1
            
        else:
            
            if good==True:
                fail=i-1
            
            good=False
            
            
            
    if good==True:
        counter=counter+1
        print(line)

        
print('counter:' ,counter)

'''
# Out:
# "\n\ncounter=0\n\ntest_reports=reports[4:5]\n\nfailed_lines=[]\n\nfail=0\n\nfor line in reports:\n    x_0=np.nan\n    good=True\n    up=False\n    down=False\n\n\n    i=0\n    \n    for number in line:\n        \n\n        if x_0 is np.nan:\n            x_0=float(number)\n            i=i+1\n            \n        elif float(number)>x_0 and (float(number)-x_0)<=3 and down==False:\n            x_0=float(number)\n            up=True\n            i=i+1\n\n            \n        elif float(number)<x_0 and (x_0-float(number))<=3 and up==False:\n            x_0=float(number)\n            down=True\n            i=i+1\n            \n        else:\n            \n            if good==True:\n                fail=i-1\n            \n            good=False\n            \n            \n                \n    if good==False:\n        \n        f_line=line[:fail] + line[fail+1:]\n        \n        failed_lines.append(f_line)\n            \n            \n    if good==True:\n        counter=counter+1\n    
# ...

# %%
counter=0


for line in reports:
    
    new_line=[]
    

    for i in range(len(line)):
        sub_line=line.copy()
        del sub_line[i]
        new_line.append(sub_line)



    good_line=False

    for mod_line in new_line:

        x_0=np.nan
        good=True
        up=False
        down=False


        i=0

        for number in mod_line:


            if x_0 is np.nan:
                x_0=float(number)
                i=i+1

            elif float(number)>x_0 and (float(number)-x_0)<=3 and down==False:
                x_0=float(number)
                up=True
                i=i+1


            elif float(number)<x_0 and (x_0-float(number))<=3 and up==False:
                x_0=float(number)
                down=True
                i=i+1

            else:
                good=False



        if good==True:
            good_line=True

    if good_line==True:
        counter=counter+1
        
print('counter:' ,counter)
# Out:
# counter: 404
